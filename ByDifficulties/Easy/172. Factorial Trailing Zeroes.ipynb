# %%
def trailingZeroes(n):
    print(n)
    return 0 if n == 0 else n / 5 + trailingZeroes(n / 5)

# %%
trailingZeroes(3)
# Out:
# 3
# 0.6
# 0.12
# 0.024
# 0.0048000000000000004
# 0.0009600000000000001
# 0.00019200000000000003
# 3.8400000000000005e-05
# 7.680000000000001e-06
# 1.5360000000000002e-06
# 3.0720000000000005e-07
# 6.144000000000001e-08
# 1.2288000000000002e-08
# 2.4576000000000003e-09
# 4.915200000000001e-10
# 9.830400000000002e-11
# 1.9660800000000003e-11
# 3.932160000000001e-12
# 7.864320000000002e-13
# 1.5728640000000002e-13
# 3.145728e-14
# 6.2914560000000006e-15
# 1.2582912000000002e-15
# 2.5165824000000005e-16
# 5.033164800000001e-17
# 1.0066329600000002e-17
# 2.0132659200000005e-18
# 4.026531840000001e-19
# 8.053063680000002e-20
# 1.6106127360000004e-20
# 3.221225472000001e-21
# 6.442450944000002e-22
# 1.2884901888000005e-22
# 2.576980377600001e-23
# 5.153960755200002e-24
# 1.0307921510400005e-24
# 2.061584302080001e-25
# 4.123168604160002e-26
# 8.246337208320004e-27
# 1.649267441664001e-27
# 3.2985348833280016e-28
# 6.597069766656003e-29
# 1.3194139533312007e-29
# 2.6388279066624014e-30
# ...
