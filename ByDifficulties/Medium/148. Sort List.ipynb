# %%
## Merge Sort Top Down
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution(object):
    def sortList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        if not head or not head.next:
            return head
        ## Slow Fast Method to find the middle
        slow, fast = head, head
        while fast.next and fast.next.next:
            slow = slow.next
            fast = fast.next.next
        lst2 = slow.next
        slow.next = None
        return self.merge(self.sortList(head), self.sortList(lst2))
    
    def merge(self, lst1, lst2):
        dummyhead = ListNode(0)
        tail = dummyhead
        while lst1 and lst2:
            if lst1.val > lst2.val:
                lst1, lst2 = lst2, lst1
            tail.next = lst1
            lst1 = lst1.next
            tail = tail.next
        if lst1:
            tail.next = lst1
        elif lst2:
            tail.next = lst2
        return dummyhead.next

# %%
## Merge Sort Bottom Up
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution(object):
    def sortList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        dummyhead = ListNode(0)
        dummyhead.next = head
        tail = dummyhead
        length = 0
        curr = head
        while curr:
            curr = curr.next
            length += 1
        n = 1
        print(length)
        while n < length:
            print(n)
            curr = dummyhead.next
            tail = dummyhead
            while curr:
                l = curr
                r = self.split(curr, n)
                curr = self.split(r, n)
                temp_head, temp_tail = self.mergeList(l, r)
                tail.next = temp_head
                tail = temp_tail
            n = n * 2
        return dummyhead.next
            
        
    def split(self, head, n):
        for i in range(n - 1):
            head = head.next
        if head:
            rest = head.next
            head.next = None
        else:
            rest = None
        return rest
    
    def mergeList(self, lst1, lst2):
        dummyhead = ListNode(0)
        tail = dummyhead
        while lst1 and lst2:
            if lst1.val > lst2.val:
                lst1, lst2 = lst2, lst1
            tail.next = lst1
            lst1 = lst1.next
            tail = tail.next
        tail.next = lst1 if lst1 else lst2
        while tail.next:
            tail = tail.next
        return dummyhead.next, tail

# %%
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution(object):
    def sortList(self, head):
        """
        :type head: ListNode
        :rtype: ListNode
        """
        if not head:
            return None
        # if not head.next.next:
        #     n = head.next
        #     head.next = None
        #      head, n
        if not head.next:
            return head
        l1, l2 = self.split(head)
        return self.merge(self.sortList(l1), self.sortList(l2))
        
        
    def split(self, head):
        slow, fast = head, head
        while fast.next and fast.next.next:
            slow = slow.next
            fast = fast.next.next
        l1 = head
        l2 = slow.next
        slow.next = None
        return l1, l2
    
    def merge(self, l1, l2):
        dummyhead = ListNode(0)
        curr = dummyhead
        while l1 and l2:
            if l1.val > l2.val:
                l1, l2 = l2, l1
            curr.next = l1
            l1 = l1.next
            curr = curr.next
        if l1:
            curr.next = l1
        if l2:
            curr.next = l2
        return dummyhead.next
