// %%
public class RandomizedSet {
    Dictionary<int, int> thisset;
    List<int> thislist;
    Random random;
    
    /** Initialize your data structure here. */
    public RandomizedSet() {
        thisset = new Dictionary<int, int>();
        thislist = new List<int>();
        random = new Random();
    }
    
    /** Inserts a value to the set. Returns true if the set did not already contain the specified element. */
    public bool Insert(int val) {
        if(!thisset.ContainsKey(val)){
            thisset[val] = thislist.Count;
            thislist.Add(val);
            return true;
        }
        return false;
    }
    
    /** Removes a value from the set. Returns true if the set contained the specified element. */
    public bool Remove(int val) {
        if(thisset.ContainsKey(val)){
            if(val == (int) thislist[thislist.Count-1]){
                thislist.RemoveAt(thislist.Count-1);
                thisset.Remove(val);
                return true;
            }
            int remove_index = thisset[val];
            int lastvalue = (int) thislist[thislist.Count-1];
            
            thislist.RemoveAt(thislist.Count - 1);
            thislist[remove_index] = lastvalue;
            
            thisset[lastvalue] = remove_index;
            thisset.Remove(val);
            return true;
        }
        return false;
    }
    
    /** Get a random element from the set. */
    public int GetRandom() {
        return thislist[random.Next(this.thislist.Count)];
    }
}

/**
 * Your RandomizedSet object will be instantiated and called as such:
 * RandomizedSet obj = new RandomizedSet();
 * bool param_1 = obj.Insert(val);
 * bool param_2 = obj.Remove(val);
 * int param_3 = obj.GetRandom();
 */
