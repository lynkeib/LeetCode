# %%
class RandomizedSet(object):

    def __init__(self):
        """
        Initialize your data structure here.
        """
        self.thisdict = dict()
        self.thislist = []
        

    def insert(self, val):
        """
        Inserts a value to the set. Returns true if the set did not already contain the specified element.
        :type val: int
        :rtype: bool
        """
        if val not in self.thisdict:
            index = len(self.thislist)
            self.thisdict[val] = index
            self.thislist.append(val)
            return True
        return False

    def remove(self, val):
        """
        Removes a value from the set. Returns true if the set contained the specified element.
        :type val: int
        :rtype: bool
        """
        if val in self.thisdict:
            remove_index = self.thisdict[val]
            if remove_index == len(self.thislist) - 1:
                self.thislist.pop()
                del self.thisdict[val]
                return True
            last = self.thislist.pop()
            this_index = self.thisdict[last]
            self.thislist[remove_index] = last
            self.thisdict[last] = remove_index
            del self.thisdict[val]
            return True
        return False

    def getRandom(self):
        """
        Get a random element from the set.
        :rtype: int
        """
        if self.thislist:
            return random.choice(self.thislist)
        return


# Your RandomizedSet object will be instantiated and called as such:
# obj = RandomizedSet()
# param_1 = obj.insert(val)
# param_2 = obj.remove(val)
# param_3 = obj.getRandom()
