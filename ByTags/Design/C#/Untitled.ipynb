// %%
public class TicTacToe {

    int[, ] grid;
    int n;

    /** Initialize your data structure here. */
    public TicTacToe (int n) {
        grid = new int[n, n];
        this.n = n;
    }

    /** Player {player} makes a move at ({row}, {col}).
        @param row The row of the board.
        @param col The column of the board.
        @param player The player, can be either 1 or 2.
        @return The current winning condition, can be either:
                0: No one wins.
                1: Player 1 wins.
                2: Player 2 wins. */
    public int Move (int row, int col, int player) {
        if (player == 1) {
            grid[row, col] = 1;
        } else {
            grid[row, col] = -1;
        }
        if (player_win (row, col, player)) {
            return player;
        }
        return 0;
    }

    public bool player_win (int row, int col, int player) {
        bool res = false;
        int check = 0, r = row, c = col;
        // chech dia
        if (row == col) {
            check = 0;
            r = row;
            c = col;
            while (r >= 0) {
                check += grid[r, c];
                r--;
                c--;
            }
            r = row;
            c = col;
            while (r < n) {
                check += grid[r, c];
                r++;
                c++;
            }
            check -= grid[row, col];
            res = res || (check == n);
            res = res || (check == -n);
            if (res) return res;
        }
        // chech dia
        if (row + col + 1 == n) {
            check = 0;
            r = row;
            c = col;
            while (r >= 0) {
                check += grid[r, c];
                r--;
                c++;
            }
            r = row;
            c = col;
            while (r < n) {
                check += grid[r, c];
                r++;
                c--;
            }
            check -= grid[row, col];
            res = res || (check == n);
            res = res || (check == -n);
            if (res) return res;
        }
        // check hor
        check = 0;
        c = col;
        r = row;
        while (c >= 0) {
            check += grid[r, c];
            c--;
        }
        c = col;
        while (c < n) {
            check += grid[r, c];
            c++;
        }
        check -= grid[row, col];
        res = res || (check == n);
        res = res || (check == -n);
        if (res) return res;
        // chech ver
        check = 0;
        c = col;
        r = row;
        while (r >= 0) {
            check += grid[r, c];
            r--;
        }
        r = row;
        while (r < n) {
            check += grid[r, c];
            r++;
        }
        check -= grid[row, col];
        res = res || (check == n);
        res = res || (check == -n);
        return res;
    }
}

/**
 * Your TicTacToe object will be instantiated and called as such:
 * TicTacToe obj = new TicTacToe(n);
 * int param_1 = obj.Move(row,col,player);
 */

// %%
public class TicTacToe {
    int[] row;
    int[] col;
    int d;
    int ad;
    int n;
    /** Initialize your data structure here. */
    public TicTacToe(int n) {
        row = new int[n];
        col = new int[n];
        d = 0;
        ad = 0;
        this.n = n;
    }
    
    /** Player {player} makes a move at ({row}, {col}).
        @param row The row of the board.
        @param col The column of the board.
        @param player The player, can be either 1 or 2.
        @return The current winning condition, can be either:
                0: No one wins.
                1: Player 1 wins.
                2: Player 2 wins. */
    public int Move(int row, int col, int player) {
        int toAdd = player == 1? 1: -1;
        this.row[row] += toAdd;
        this.col[col] += toAdd;
        if(row == col) d += toAdd;
        if(row + col + 1 == n) ad += toAdd;
        if(Math.Abs(this.row[row]) == n || Math.Abs(this.col[col]) == n || Math.Abs(d) == n || Math.Abs(ad) == n) return player;
        return 0;
    }
}

/**
 * Your TicTacToe object will be instantiated and called as such:
 * TicTacToe obj = new TicTacToe(n);
 * int param_1 = obj.Move(row,col,player);
 */
