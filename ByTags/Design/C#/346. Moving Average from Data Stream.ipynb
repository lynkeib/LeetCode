// %%
public class MovingAverage {

    int?[] nums;
    int index;
    int sum;
    int size;

    /** Initialize your data structure here. */
    public MovingAverage (int size) {
        nums = new int?[size];
        for (int i = 0; i < size; i++) {
            nums[i] = null;
        }
        index = 0;
        sum = 0;
        this.size = size;
    }

    public double Next (int val) {
        if(nums[index] == null){
            nums[index] = val;
            sum += val;
            double res = sum * 1.0 / (index + 1);
            index = (index + 1) % size;
            return res;
        }else{
            sum -= (int) nums[index];
            sum += val;
            nums[index] = (int?) val;
            index = (index + 1) % size;
            return sum * 1.0 / size;
        }
    }
}

/**
 * Your MovingAverage object will be instantiated and called as such:
 * MovingAverage obj = new MovingAverage(size);
 * double param_1 = obj.Next(val);
 */

// %%
public class MovingAverage {

    Queue<int> queue;
    int sum;
    int size;

    /** Initialize your data structure here. */
    public MovingAverage (int size) {
        queue = new Queue<int> ();
        sum = 0;
        this.size = size;
    }

    public double Next (int val) {
        queue.Enqueue (val);
        if (queue.Count > size) {

            sum -= queue.Dequeue ();
        }
        sum += val;
        return sum * 1.0 / queue.Count;
    }
}

/**
 * Your MovingAverage object will be instantiated and called as such:
 * MovingAverage obj = new MovingAverage(size);
 * double param_1 = obj.Next(val);
 */
