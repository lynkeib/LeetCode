// %%
public class Vector2D {

    public int list_index;
    public int array_index;
    public int[][] v;
    
    public Vector2D(int[][] v) {
        list_index = 0;
        array_index = 0;
        this.v = v;
    }
    
    public int Next() {
        while(v[list_index].Length == 0){
            list_index++;
            array_index = 0;
        }
        int res = v[list_index][array_index];
        array_index ++;
        if(array_index >= v[list_index].Length){
            list_index += 1;
            array_index = 0;
        }
        return res;
    }
    
    public bool HasNext() {
        while(list_index < v.Length && v[list_index].Length == 0){
            list_index++;
            array_index = 0;
        }
        if(list_index == v.Length ||  (list_index == v.Length - 1 && v[list_index].Length == 0)) return false;
        return true;
    }
}

/**
 * Your Vector2D object will be instantiated and called as such:
 * Vector2D obj = new Vector2D(v);
 * int param_1 = obj.Next();
 * bool param_2 = obj.HasNext();
 */

// %%
public class Vector2D {

    public int list_index;
    public int array_index;
    public int[][] v;
    
    public Vector2D(int[][] v) {
        list_index = 0;
        array_index = 0;
        this.v = v;
    }
    
    public int Next() {
        int res = v[list_index][array_index];
        array_index ++;
        HasNext();
        return res;
    }
    
    public bool HasNext() {
        while(list_index < v.Length && array_index >= v[list_index].Length ){
            list_index++;
            array_index = 0;
        }
        return list_index < v.Length;
    }
}

/**
 * Your Vector2D object will be instantiated and called as such:
 * Vector2D obj = new Vector2D(v);
 * int param_1 = obj.Next();
 * bool param_2 = obj.HasNext();
 */
